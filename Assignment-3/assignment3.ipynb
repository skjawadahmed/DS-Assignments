# %% [markdown]
# # ASSIGNMENT 3 - Basic statistics

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
#Load the dataset
df = pd.read_csv("sales_data_with_discounts.csv")

# %%
# Display first few rows
print("Dataset Preview:")
print(df.head())
# Out:
# Dataset Preview:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# ...

# %%
# Identify all numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Numerical Columns:", num_cols)
# Out:
# Numerical Columns: ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']

# %%
# Calculate basic statistics for numerical columns
desc_stats = pd.DataFrame({
    'Mean': df[num_cols].mean(),
    'Median': df[num_cols].median(),
    'Mode': [df[c].mode()[0] for c in num_cols],
    'Standard Deviation': df[num_cols].std()
})

print("\nDescriptive Statistics:\n")
print(desc_stats)
# Out:
# Descriptive Statistics:
#
#                            Mean       Median          Mode  Standard Deviation
# Volume                 5.066667     4.000000      3.000000            4.231602
# Avg Price          10453.433333  1450.000000    400.000000        18079.904840
# Total Sales Value  33812.835556  5700.000000  24300.000000        50535.074173
# Discount Rate (%)     15.155242    16.577766      5.007822            4.220602
# Discount Amount     3346.499424   988.933733     69.177942         4509.902963
# Net Sales Value    30466.336131  4677.788059    326.974801        46358.656624

# %% [markdown]
# # HISTOGRAM PLOTS

# %%
#Plot histograms for each numerical column
for col in num_cols:
    plt.figure(figsize=(6,4))
    plt.hist(df[col], bins=20, color='skyblue', edgecolor='black')
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.grid(axis='y', alpha=0.75)
    plt.show()

# %% [markdown]
# # BOX PLOTS

# %%
# Create boxplots for each numerical column
for col in num_cols:
    plt.figure(figsize=(6,3))
    plt.boxplot(df[col], vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# # BAR CHARTS

# %%
# Identify main categorical columns for visualization
categorical_cols = ['Day', 'City', 'BU', 'Brand']

# Plot bar charts for each categorical column
for col in categorical_cols:
    plt.figure(figsize=(7, 5))
    sns.countplot(x=col, data=df, hue=col, legend=False, palette='Set2',
                  order=df[col].value_counts().index)
    plt.title(f'Bar Chart for {col}', fontsize=14, weight='bold')
    plt.xlabel(col, fontsize=12)
    plt.ylabel('Count', fontsize=12)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# # DESCRIPTIVE ANALYTICS
# # From the descriptive analytics and visualizations, we can clearly understand the overall sales and discount patterns in the dataset. The numerical analysis gave an idea of the average sales values, pricing, and discount rates, helping us see how the data is spread out.

# %% [markdown]
# # VISUALISATION
# # The visualizations made the data easier to interpret. The histograms and box plots showed that most sales values are grouped within a certain range, while a few products had higher values — possibly premium items.

# %% [markdown]
# # BAR CHART
# # From the bar chart analysis, we noticed that the Mobiles and FMCG business units are the main contributors to sales. Among the brands, RealU, YouM, and Sumsang had the most records, showing they are the most active or popular brands in the dataset. All sales were recorded on Thursday in City C, which means the data might be from one location or one particular day’s sales.
